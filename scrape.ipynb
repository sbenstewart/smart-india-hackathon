# %%
import pytest
import time
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
import os
import glob
import pandas as pd
import subprocess
import shutil

# %%
path = '/Users/benstewart/BEN STUFF/PROJECTS/smart-india-hackathon/datasets/INDIA'

# %%
chrome_options = webdriver.ChromeOptions()
prefs = {'download.default_directory' : path}
chrome_options.add_experimental_option('prefs', prefs)

# %%
shutil.rmtree(path)
os.mkdir(path)

# %%
driver = webdriver.Chrome(options=chrome_options)
driver.implicitly_wait(2)

# %%
try:
    driver.get("http://59.179.19.250/GWL/GWL.html")
    driver.set_window_size(1235, 777)
    dropdown = driver.find_element(By.ID, "State_combo")
    options = [x for x in dropdown.find_elements_by_tag_name("option")]
    for element in options:
        print(element.get_attribute("value")) 
        element.click()
        time.sleep(1)
        dropdown = driver.find_element(By.ID, "district_combo")
        options = [x for x in dropdown.find_elements_by_tag_name("option")]
        for element in options:
            print(element.get_attribute("value")) 
            element.click()
            driver.find_element(By.ID, "datadownload_butt").click()
finally:
    driver.quit()
# Out:
# NULL
# AP
# NA
# Anantapur
# Chittoor
# East Godavari
# Guntur
# Krishna
# Kurnool
# Prakasam
# Sri Potti Sriramulu Nellore
# Srikakulam
# Visakhapatnam
# Vizianagaram
# West Godavari
# Y.s.r.
# AN
# NA
# North & Middle Andaman
# South Andaman
# AR
# NA
# Changlang
# East Siang
# Lohit
# Papum Pare
# Tirap
# AS
# NA
# Baksa
# Barpeta
# Bongaigaon
# Cachar
# Chirang
# Darrang
# Dhemaji
# Dhubri
# Dibrugarh
# Goalpara
# Golaghat
# Hailakandi
# Jorhat
# Kamrup
# Kamrup Metropolitan
# Karbi Anglong
# Karimganj
# Kokrajhar
# Lakhimpur
# Marigaon
# Nagaon
# Nalbari
# Sivasagar
# Sonitpur
# Tinsukia
# Udalguri
# BR
# NA
# Araria
# Arwal
# Aurangabad
# Banka
# Begusarai
# Bhagalpur
# Bhojpur
# Buxar
# Darbhanga
# Gaya
# Gopalganj
# Jamui
# Jehanabad
# Kaimur (bhabua)
# Katihar
# Khagaria
# Kishanganj
# Lakhisarai
# Madhepura
# Madhubani
# Munger
# Muzaffarpur
# Nalanda
# Nawada
# Pashchim Champaran
# Patna
# Purba Champaran
# Purnia
# Rohtas
# Saharsa
# Samastipur
# Saran (chhapra)
# ...

# %%
os.chdir(path)
os.system("awk '(NR == 1) || (FNR > 1)' web*.csv > ../combined_csv.csv")
# Out:
# 0

# %%
'''
extension = 'csv'
os.chdir(path)
result = glob.glob('*.{}'.format(extension))
#print(result)
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in result ])
#export to csv
path = '/Users/benstewart/BEN STUFF/PROJECTS/smart-india-hackathon/datasets'
os.chdir(path)
combined_csv.to_csv("combined_csv.csv", index=False, encoding='utf-8-sig')
path = '/Users/benstewart/BEN STUFF/PROJECTS/smart-india-hackathon'
os.chdir(path)
'''
# Out:
# '\nextension = \'csv\'\nos.chdir(path)\nresult = glob.glob(\'*.{}\'.format(extension))\n#print(result)\n#combine all files in the list\ncombined_csv = pd.concat([pd.read_csv(f) for f in result ])\n#export to csv\npath = \'/Users/benstewart/BEN STUFF/PROJECTS/smart-india-hackathon/datasets\'\nos.chdir(path)\ncombined_csv.to_csv("combined_csv.csv", index=False, encoding=\'utf-8-sig\')\npath = \'/Users/benstewart/BEN STUFF/PROJECTS/smart-india-hackathon\'\nos.chdir(path)\n'
